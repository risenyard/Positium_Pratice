# %%
import geopandas as gpd
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import mapclassify as mc

# %%
# read the world geometry data exported form Task 1
data = gpd.read_file('Task-2-Data/Task-2-Exported-Geomeries.gpkg')
# get the 
# define the crs
crs= ccrs.EckertIV()
# project the data
data=data.to_crs(crs)
# Out:
# <Axes: >

# %%
# establish a canvas
fig = plt.figure(figsize=(10, 5))
# set up and ax object
ax = fig.add_subplot(1, 1, 1, projection=crs)

# Set the extent and crs of the map
#ax.set_extent([-50, 50, -90, 90],crs)
ax.set_global()
# Set parameters of the ax
for spine in ax.spines.values():
    spine.set_linewidth(1)
    spine.set_color('grey')

ax.add_geometries(geoms,crs,facecolor='none',edgecolor='grey',linewidth=0.2)
# 添加海岸线、边界和地图特征
#ax.add_feature(cfeature.COASTLINE,facecolor='none',edgecolor='black',linewidth=0.5)
#ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
#ax.add_feature(cfeature.LAND)

#ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor=cfeature.COLORS['land']))
#ax.add_feature(cfeature.NaturalEarthFeature('physical', 'ocean', '110m', edgecolor='face', facecolor=cfeature.COLORS['water']))
# 将geodataframe转换为shapely geometry对象，并添加到地图上

#set title
ax.set_title("GDP in 2019 for all Countries",)
ax.title.set_fontname('times new roman')
ax.title.set_fontsize(16)




# 显示地图
plt.show()

# %%
ax.add_geometries(geoms,crs,facecolor='none',edgecolor='grey',linewidth=0.2)
# 添加海岸线、边界和地图特征
#ax.add_feature(cfeature.COASTLINE,facecolor='none',edgecolor='black',linewidth=0.1)
#ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
#ax.add_feature(cfeature.LAND)

#ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor=cfeature.COLORS['land']))
#ax.add_feature(cfeature.NaturalEarthFeature('physical', 'ocean', '10m', edgecolor='face', facecolor=cfeature.COLORS['water']))
# 将geodataframe转换为shapely geometry对象，并添加到地图上


# 显示地图
plt.show()

# %%
plt.show()
